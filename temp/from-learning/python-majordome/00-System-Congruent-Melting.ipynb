# %% [markdown]
# # Systems with congruent melting

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from presim.utilities import Capturing
from presim.calphad.samples import simulate_pure_al2o3
from presim.calphad.samples import simulate_pure_cao
from presim.calphad.samples import simulate_pure_sio2
from presim.calphad.samples import simulate_pure_c1a1
from presim.calphad.samples import simulate_pure_c1a2
from presim.calphad.samples import simulate_pure_c12a7
from presim.calphad.samples import plot_pure_al2o3_gibbs
from presim.calphad.samples import plot_pure_cao_gibbs
from presim.calphad.samples import plot_pure_sio2_gibbs
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ---
#
# ## $Al_2O_3$

# %%
# %%time

with Capturing():
    simulate_pure_al2o3()
# Out:
# CPU times: total: 531 ms
# Wall time: 548 ms

# %%
with Capturing():
    plot_pure_al2o3_gibbs()

# %% [markdown]
# ---
# ## $CaO$

# %%
# %%time
with Capturing():
    simulate_pure_cao()
# Out:
# CPU times: total: 344 ms
# Wall time: 342 ms

# %%
with Capturing():
    plot_pure_cao_gibbs()

# %% [markdown]
# ---
#
# ## $SiO_2$

# %%
# %%time
with Capturing():
    simulate_pure_sio2()
# Out:
# CPU times: total: 2.94 s
# Wall time: 2.96 s

# %%
with Capturing():
    plot_pure_sio2_gibbs()

# %% [markdown]
# ---
#
# ## $1CaO\cdotp{}1Al_2O_3$ ($C_1A_1$)

# %%
# %%time
with Capturing():
    simulate_pure_c1a1()
# Out:
# CPU times: total: 609 ms
# Wall time: 611 ms

# %% [markdown]
# ---
# ## $1CaO\cdotp{}2Al_2O_3$ ($C_1A_2$)

# %%
# %%time
with Capturing():
    simulate_pure_c1a2()
# Out:
# CPU times: total: 1.91 s
# Wall time: 1.9 s

# %% [markdown]
# ---
# ## $12CaO\cdotp{}7Al_2O_3$ ($C_{12}A_{7}$)

# %%
# %%time
with Capturing():
    simulate_pure_c12a7()
# Out:
# CPU times: total: 1.03 s
# Wall time: 1.01 s
