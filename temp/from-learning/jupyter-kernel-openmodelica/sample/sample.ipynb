# %% [markdown]
# # Jupyter OpenModelica Kernel

# %% [markdown]
# An example interaction of OpenModelica in Jupyter Notebook is presented below.

# %%
class Pendulum "Planar Pendulum"
   constant Real PI=3.141592653589793;
   parameter Real m=1, g=9.81, L=0.5;
   Real F;
   output Real x(start=0.5),y(start=0);
   output Real vx,vy;
equation
   m*der(vx)=-(x/L)*F;
   m*der(vy)=-(y/L)*F-m*g;
   der(x)=vx;
   der(y)=vy;
   x^2+y^2=L^2;
end Pendulum;
# Out:
# ('Pendulum',)

# %%
simulate(Pendulum)
# Out:
# {'resultFile': 'D:/WallyTutor/learning-scientific-computing/tools/jupyter-kernel-openmodelica/sample/Pendulum_res.mat', 'simulationOptions': "startTime = 0.0, stopTime = 1.0, numberOfIntervals = 500, tolerance = 1e-06, method = 'dassl', fileNamePrefix = 'Pendulum', options = '', outputFormat = 'mat', variableFilter = '.*', cflags = '', simflags = ''", 'messages': 'LOG_SUCCESS       | info    | The initialization finished successfully without homotopy method.\nLOG_SUCCESS       | info    | The simulation finished successfully.\n', 'timeFrontend': 0.0028611, 'timeBackend': 0.0510232, 'timeSimCode': 0.009291, 'timeTemplates': 0.0101213, 'timeCompile': 3.3694718, 'timeSimulation': 0.1052693, 'timeTotal': 3.5483312}

# %%
plot(der(x),der(y),m)

# %%
type GreenClass = Real(unit = "green");
# Out:
# ('GreenClass',)

# %%
type YellowClass = Real(unit = "yellow");
# Out:
# ('YellowClass',)

# %%
class C
  replaceable GreenClass  obj1(p1=5);
  replaceable YellowClass obj2;
  replaceable GreenClass  obj3;
end C;
# Out:
# ('C',)

# %%
class C2 = C(redeclare RedClass obj1, redeclare GreenClass obj2);
# Out:
# ('C2',)

# %%
class C2b
  RedClass obj1(p1=5);    //type
  GreenClass obj2;
  GreenClass obj3;
end C2b;
# Out:
# ('C2b',)

# %%
type BlueClass = Real(unit = "blue");
# Out:
# ('BlueClass',)

# %%
class C
  replaceable class ColoredClass = GreenClass;  //type parameter
  ColoredClass         obj1(p1 = 5);
  replaceable YellowClass obj2;
  ColoredClass         obj3;
end C;
# Out:
# ('C',)

# %%
package SmallPack

  constant Real mypi = 3.14159;

  connector Pin
    Voltage v;
    flow Current i;
  end Pin;

  function multiply
    input Real x;
    input Real y = 0;
    output Real result;
  algorithm
    result := x*y;
  end multiply;

end SmallPack;
# Out:
# ('SmallPack',)

# %%
model Resistor "Electrical resistor"
   Pin p, n "positive and negative pins";
   Voltage v;
   Current i;
   parameter Real R(unit="Ohm") "Resistance";
equation
   v = i*R;
end Resistor;
# Out:
# ('Resistor',)

# %%
loadModel(Modelica)
# Out:
# True

# %%
block Multiply
  input Real x;
  input Real y(start=0);
  output Real result;
equation
  result = x*y;
end Multiply;
# Out:
# ('Multiply',)
